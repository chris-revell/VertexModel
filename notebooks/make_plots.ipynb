# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from glob import glob

# %%
files=glob("C:\\Documents\\VM_code\\VertexModel\\data\\sims/pseudo2D/500_cells/Final_config/data*.csv")
savedir="\\Documents\\VM_code\\VertexModel\\data\\sims/pseudo2D/500_cells/Final_config/"




df = pd.concat((pd.read_csv(f, names=['Gamma_a', 'Gamma_A', 'Gamma_L', 'L_0','H', 'Edges','A', 'L', 'T2D', 'P2D' ]) for f in files), ignore_index=True)

# %%
df["shape_param"]=df.L/np.sqrt(df.A)
df["Ph"]=(df.A*df.H-1)
df["Th"]=df.Gamma_a*(2*df.A+df.H*df.L-1)
df["Thc"]=2*df.Gamma_L*(df.L-df.L_0)
df["V"]=df.A*df.H
df["a"]=2*df.A+df.H*df.L

# %%
sn=[4., 3.81194, 3.72242, 3.67207, 3.64072]

# %%
#from analytics
L0_x=np.array([-1.16878, -1.06878, -0.968782, -0.868782, -0.768782, -0.668782, \
-0.568782, -0.468782, -0.368782, -0.268782, -0.168782, -0.0687824, \
0.0312176, 0.131218, 0.231218, 0.331218, 0.431218, 0.531218, \
0.631218, 0.731218, 0.831218, 0.931218, 1.03122, 1.13122, 1.23122, \
1.33122, 1.43122, 1.53122, 1.63122, 1.73122, 1.83122, 1.93122, \
2.03122, 2.13122, 2.23122, 2.33122, 2.43122, 2.53122, 2.63122, \
2.73122, 2.83122, 2.93122, 3.03122, 3.13122, 3.23122, 3.33122, \
3.43122, 3.53122, 3.63122, 3.73122, 3.83122, 3.93122, 4.03122, \
4.13122, 4.23122, 4.33122, 4.43122, 4.53122, 4.63122, 4.73122, \
4.83122, 4.93122, 5.03122, 5.13122, 5.23122, 5.33122, 5.43122, \
5.53122, 5.63122, 5.73122, 5.83122, 5.93122, 6.03122, 6.13122, \
6.23122, 6.33122, 6.43122, 6.53122, 6.63122, 6.73122, 6.83122, 6.93122])
A_6_L0=np.array([0.000307678, 0.00126744, 0.00282492, 0.00493494, 0.00756066, \
0.0106719, 0.014244, 0.0182568, 0.0226939, 0.0275421, 0.032791, \
0.0384324, 0.0444603, 0.0508704, 0.05766, 0.064828, 0.0723744, \
0.0803003, 0.088608, 0.0973008, 0.106383, 0.115859, 0.125735, \
0.136017, 0.146712, 0.157828, 0.169373, 0.181356, 0.193786, 0.206671, \
0.220023, 0.23385, 0.248163, 0.262972, 0.278287, 0.294117, 0.310474, \
0.327365, 0.3448, 0.362787, 0.381333, 0.384777, 0.386855, 0.387621, \
0.387136, 0.385467, 0.382683, 0.378855, 0.374058, 0.368363, 0.361843, \
0.35457, 0.346611, 0.338032, 0.328896, 0.319262, 0.309185, 0.298716, \
0.287904, 0.276791, 0.265418, 0.253823, 0.242037, 0.230092, 0.218015, \
0.205829, 0.193557, 0.181219, 0.168831, 0.15641, 0.143968, 0.131517, \
0.119069, 0.106633, 0.0942152, 0.0818241, 0.0694654, 0.0571443, \
0.0448651, 0.0326317, 0.0204472, 0.00831425])
L_6_L0=np.array([0.065294, 0.132523, 0.197846, 0.261497, 0.323672, 0.384544, 0.444264, \
11.7352, 11.3368, 10.9386, 10.5405, 10.1424, 9.74456, 9.34683, \
8.94927, 8.5519, 8.15474, 7.75781, 7.36116, 6.96481, 6.56882, \
6.17301, 5.58371, 5.02905, 4.50868, 4.02219, 3.56901, 3.14839, \
2.75937, 2.40071, 2.0709, 1.7681, 1.49014, 1.23454, 0.99851, \
0.778991, 0.572618, 0.375673, 0.183921, -0.00772377])

# %%
T2D_6_L0=H_6_L0*((-0.5/2.)+0.1*(2*A_6_L0+L_6_L0*H_6_L0-1)) + 2*0.1*(L_6_L0-L0_x)
T2D_6_Ga=H_6_Ga*((-0.5/2.)+Ga_x*(2*A_6_Ga+L_6_Ga*H_6_Ga-1)) + 2*0.1*(L_6_Ga-2)
T2D_6_GA=H_6_GA*((GA_x/2.)+0.1*(2*A_6_GA+L_6_GA*H_6_GA-1)) + 2*0.1*(L_6_GA-2)

# %%
g=sns.pointplot(data=df[(df.Gamma_a==0.1)&(df.Gamma_A==-0.5)], x="L_0", y="H", native_scale=True, markersize=4)

g.set_xlabel(r"$L_0$")
g.set_ylabel(r"$H$")
g.set_title("Cell Height")
plt.plot(L0_x, H_6_L0, c='k', zorder=0)
plt.xlim(2.7,3)
plt.ylim(1.25, 1.75)
plt.show()

# g=sns.pointplot(data=df[(df.L_0==2.0)&(df.Gamma_A==-0.5)], x="Gamma_a", y="H", native_scale=True, markersize=4)

# g.set_xlabel(r"$\Gamma_a$")
# g.set_ylabel(r"$H$")
# g.set_title("Cell Height")
# plt.plot(Ga_x, H_6_Ga, c='k', zorder=0)
# plt.xlim(0,0.6)
# plt.ylim(0.7, 5)

# plt.show()


# g=sns.pointplot(data=df[(df.L_0==2.0)&(df.Gamma_a==0.1)], x="Gamma_A", y="H", native_scale=True, markersize=4)
# g.set_xlabel(r"$\Gamma_A$")
# g.set_ylabel(r"$H$")
# g.set_title("Cell Height")

# plt.plot(GA_x, H_6_GA, c='k', zorder=0)
# plt.xlim(-1.65,-0.45)
# plt.ylim(1.9, 7)

# %%
g=sns.lineplot(data=df[(df.Gamma_a==0.1)&(df.Gamma_A==-0.5)], x="L_0", y="shape_param",hue="Edges", palette=sns.color_palette("colorblind", n_colors=5), err_style='bars', errorbar='sd')

sns.move_legend(g, "upper left", bbox_to_anchor=(1, 1))
g.set_xlabel(r"$L_0$")
g.set_ylabel(r"$\frac{L}{\sqrt{A}}$", rotation=0)
g.set_title("Mean Shape Parameter")
#plt.axhline(3.85, c='lightgrey')
plt.axhline(3.81, c='lightgrey')
plt.axvline(2.78417, c='lightgrey')
plt.axvline(2.80231, c='lightgrey')
plt.axvline(2.83122, c='lightgrey')
plt.axvline(2.88194, c='lightgrey')
plt.axvline(2.98577, c='lightgrey')
plt.plot(L0_x, L_6_L0/np.sqrt(A_6_L0), c='k', zorder=0)

plt.xlim(2.75,3)
plt.ylim(3.72, 3.95)

plt.show()

g=sns.lineplot(data=df[(df.L_0==2.0)&(df.Gamma_A==-0.5)], x="Gamma_a", y="shape_param",hue="Edges", palette=sns.color_palette("colorblind", n_colors=5), err_style='bars', errorbar='sd')
sns.move_legend(g, "upper left", bbox_to_anchor=(1, 1))
g.set_xlabel(r"$\Gamma_a$")
g.set_ylabel(r"$\frac{L}{\sqrt{A}}$", rotation=0)
g.set_title("Mean Shape Parameter")
plt.axhline(4, c='lightgrey')
plt.axhline(3.81, c='lightgrey')

plt.show()
g=sns.lineplot(data=df[(df.L_0==2.0)&(df.Gamma_A==-0.5)], x="Gamma_a", y="shape_param",hue="Edges", palette=sns.color_palette("colorblind", n_colors=5), err_style='bars', errorbar='sd')
sns.move_legend(g, "upper left", bbox_to_anchor=(1, 1))
g.set_xlabel(r"$\Gamma_a$")
g.set_ylabel(r"$\frac{L}{\sqrt{A}}$", rotation=0)
g.set_title("Mean Shape Parameter")
plt.axhline(4, c='lightgrey')
plt.axhline(3.81, c='lightgrey')

plt.xlim(0.49,0.54)
plt.ylim(3.75, 3.95)


plt.show()
g=sns.lineplot(data=df[(df.L_0==2.0)&(df.Gamma_A==-0.5)], x="Gamma_a", y="shape_param",hue="Edges", palette=sns.color_palette("colorblind", n_colors=5), err_style='bars', errorbar='sd')
sns.move_legend(g, "upper left", bbox_to_anchor=(1, 1))
g.set_xlabel(r"$\Gamma_a$")
g.set_ylabel(r"$\frac{L}{\sqrt{A}}$", rotation=0)
g.set_title("Mean Shape Parameter")
plt.axhline(4, c='lightgrey')
plt.axhline(3.81, c='lightgrey')

plt.xlim(0.03,0.051)
plt.ylim(3.75, 3.95)



plt.show()

g=sns.lineplot(data=df[(df.L_0==2.0)&(df.Gamma_a==0.1)], x="Gamma_A", y="shape_param",hue="Edges", palette=sns.color_palette("colorblind", n_colors=5), err_style='bars', errorbar='sd')
sns.move_legend(g, "upper left", bbox_to_anchor=(1, 1))
g.set_xlabel(r"$\Gamma_A$")
g.set_ylabel(r"$\frac{L}{\sqrt{A}}$", rotation=0)
g.set_title("Mean Shape Parameter")
plt.axhline(4, c='lightgrey')
plt.axhline(3.81, c='lightgrey')

# %%
g=sns.lineplot(data=df[(df.Gamma_a==0.1)&(df.Gamma_A==-0.5)], x="L_0", y="shape_param",hue="Edges", palette=sns.color_palette("colorblind", n_colors=5), err_style='bars',estimator='median' )

sns.move_legend(g, "upper left", bbox_to_anchor=(1, 1))
g.set_xlabel(r"$L_0$")
g.set_ylabel(r"$\frac{L}{\sqrt{A}}$", rotation=0)
g.set_title("Median Shape Parameter")
plt.axhline(4, c='lightgrey')
plt.axhline(3.81, c='lightgrey')
plt.axvline(2.78417, c='lightgrey')
plt.axvline(2.80231, c='lightgrey')
plt.axvline(2.83122, c='lightgrey')
plt.axvline(2.88194, c='lightgrey')
plt.axvline(2.98577, c='lightgrey')

plt.show()

g=sns.lineplot(data=df[(df.L_0==2)&(df.Gamma_A==-0.5)], x="Gamma_a", y="shape_param",hue="Edges", palette=sns.color_palette("colorblind", n_colors=5), err_style='bars',estimator='median' )

sns.move_legend(g, "upper left", bbox_to_anchor=(1, 1))
g.set_xlabel(r"$\Gamma_a$")
g.set_ylabel(r"$\frac{L}{\sqrt{A}}$", rotation=0)
g.set_title("Median Shape Parameter")
plt.axhline(4, c='lightgrey')
plt.axhline(3.81, c='lightgrey')

plt.show()
g=sns.lineplot(data=df[(df.L_0==2)&(df.Gamma_a==0.1)], x="Gamma_A", y="shape_param",hue="Edges", palette=sns.color_palette("colorblind", n_colors=5), err_style='bars',estimator='median' )

sns.move_legend(g, "upper left", bbox_to_anchor=(1, 1))
g.set_xlabel(r"$\Gamma_A$")
g.set_ylabel(r"$\frac{L}{\sqrt{A}}$", rotation=0)
g.set_title("Median Shape Parameter")
plt.axhline(4, c='lightgrey')
plt.axhline(3.81, c='lightgrey')

# %%
#fig, ax = plt.subplots(figsize=(10,10))
g=sns.catplot(data=df[(df.Gamma_a==0.1)&(df.Gamma_A==-0.5)&(df.L_0.isin([2.85,2.875, 2.9, 2.95]))], x="L_0", y="shape_param",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)
g.fig.set_size_inches(6,7)

#ax = g.ax

#plt.plot([0,1,2],[3.75539, 3.84418,3.93447], c='red', marker='o', zorder=10, linestyle='--'  )


g.set_axis_labels(r"$L_0$", r"$\frac{L}{\sqrt{A}}$", rotation=0, fontsize=16)
g.refline(y=4)
g.refline(y=3.81)
# Out:
# C:\Users\v35431nc\AppData\Local\Temp\ipykernel_11096\677900046.py:2: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   g=sns.catplot(data=df[(df.Gamma_a==0.1)&(df.Gamma_A==-0.5)&(df.L_0.isin([2.85,2.875, 2.9, 2.95]))], x="L_0", y="shape_param",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)

# %%
#fig, ax = plt.subplots(figsize=(10,10))
g=sns.catplot(data=df[(df.Gamma_a==0.1)&(df.Gamma_A==-0.5)&(df.L_0.isin([2.85, 2.875,2.9, 2.925,2.95]))], x="L_0", y="shape_param",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)
g.fig.set_size_inches(6,7)

#ax = g.ax

#plt.plot([0,1,2],[3.75539, 3.84418,3.93447], c='red', marker='o', zorder=10, linestyle='--'  )


g.set_axis_labels(r"$L_0$", r"$\frac{L}{\sqrt{A}}$", rotation=0, fontsize=16)
g.refline(y=4)
g.refline(y=3.81)
# Out:
# C:\Users\v35431nc\AppData\Local\Temp\ipykernel_30300\1533859489.py:2: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   g=sns.catplot(data=df[(df.Gamma_a==0.1)&(df.Gamma_A==-0.5)&(df.L_0.isin([2.85, 2.875,2.9, 2.925,2.95]))], x="L_0", y="shape_param",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)

# %%
plt.figure()
g=sns.catplot(data=df[(df.Gamma_a==0.1)&(df.Gamma_A==-0.5)&(df.L_0.isin([2.85,2.86, 2.87, 2.88, 2.89, 2.9, 2.95]))], x="L_0", y="shape_param",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)
#ax = g.ax

plt.plot([0,1,2,3,4,5],[3.75539, 3.77303, 3.79073, 3.80849, 3.8263, 3.84418], c='red', marker='o', zorder=10, linestyle='--'  )
plt.scatter([6], [3.93447], c='red', zorder=10)

g.set_axis_labels(r"$L_0$", r"$\frac{L}{\sqrt{A}}$", rotation=0, fontsize=14)
g.refline(y=4)
g.refline(y=3.81)
d = .005  # how big to make the diagonal lines in axes coordinates
# arguments to pass plot, just so we don't keep repeating them
plt.plot((5.45, 5.55), (3.73, 3.73), color='w', clip_on=False, linewidth=2, zorder=3)
kwargs = dict( color='k', clip_on=False)
plt.plot((5.45-4*d, 5.45+4*d), (3.73-d, 3.73+d), **kwargs, zorder=4)
plt.plot((5.55-4*d, 5.55+4*d), (3.73-d, 3.73+d), **kwargs, zorder=4)
plt.ylim(3.73,4.02)
# Out:
# C:\Users\v35431nc\AppData\Local\Temp\ipykernel_11096\3211690833.py:2: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   g=sns.catplot(data=df[(df.Gamma_a==0.1)&(df.Gamma_A==-0.5)&(df.L_0.isin([2.85,2.86, 2.87, 2.88, 2.89, 2.9, 2.95]))], x="L_0", y="shape_param",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)
# (3.73, 4.02)

# %%
g=sns.catplot(data=df[(df.Gamma_a==0.1)&(df.Gamma_A==-0.5)], x="L_0", y="shape_param",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)
g.set_axis_labels(r"$L_0$", "Shape Parameter")
g.refline(y=4.0)
g.refline(y=3.81)
g.refline(y=3.72)
#g.savefig(savedir+"Shape_parameter_L_0.png")
# Out:
# C:\Users\v35431nc\AppData\Local\Temp\ipykernel_33196\810366976.py:1: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   g=sns.catplot(data=df[(df.Gamma_a==0.1)&(df.Gamma_A==-0.5)], x="L_0", y="shape_param",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)

# %%
g=sns.catplot(data=df[(df.L_0==2.0)&(df.Gamma_A==-0.5)&(df.Gamma_a>=0.505)], x="Gamma_a", y="shape_param",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)
g.set_axis_labels(r"$\Gamma_a$", "Shape Parameter")
g.refline(y=3.81)

plt.plot([0,1,2,3,4,],[ 3.72, 3.75841, 3.81826, 3.87546, 3.93041], c='red', marker='o', zorder=10  )


#zg.savefig(savedir+"Shape_parameter_Gamma_a.png")
# Out:
# C:\Users\v35431nc\AppData\Local\Temp\ipykernel_16764\756537055.py:1: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   g=sns.catplot(data=df[(df.L_0==2.0)&(df.Gamma_A==-0.5)&(df.Gamma_a>=0.505)], x="Gamma_a", y="shape_param",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)

# %%
g=sns.catplot(data=df[(df.L_0==2.0)&(df.Gamma_A==-0.5)&(df.Gamma_a<=0.04)], x="Gamma_a", y="shape_param",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)
g.set_axis_labels(r"$\Gamma_a$", "Shape Parameter")
g.refline(y=3.81)
# Out:
# C:\Users\v35431nc\AppData\Local\Temp\ipykernel_16764\1139959614.py:1: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   g=sns.catplot(data=df[(df.L_0==2.0)&(df.Gamma_A==-0.5)&(df.Gamma_a<=0.04)], x="Gamma_a", y="shape_param",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)

# %%
g=sns.catplot(data=df[(df.L_0==2.0)&(df.Gamma_A==-0.5)], x="Gamma_a", y="shape_param",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)
g.set_axis_labels(r"$\Gamma_a$", "Shape Parameter")

g.refline(y=4.0)
g.refline(y=3.81)
g.refline(y=3.72)

#zg.savefig(savedir+"Shape_parameter_Gamma_a.png")
# Out:
# C:\Users\v35431nc\AppData\Local\Temp\ipykernel_16764\3248741985.py:1: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   g=sns.catplot(data=df[(df.L_0==2.0)&(df.Gamma_A==-0.5)], x="Gamma_a", y="shape_param",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)

# %%
g=sns.catplot(data=df[(df.L_0==2.0)&(df.Gamma_a==0.1)], x="Gamma_A", y="shape_param",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)
g.set_axis_labels(r"$\Gamma_A$", "Shape Parameter")
g.refline(y=4.0)
g.refline(y=3.81)
g.refline(y=3.72)
#g.savefig(savedir+"Shape_parameter_Gamma_A.png")
# Out:
# C:\Users\v35431nc\AppData\Local\Temp\ipykernel_16764\4287846954.py:1: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   g=sns.catplot(data=df[(df.L_0==2.0)&(df.Gamma_a==0.1)], x="Gamma_A", y="shape_param",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)

# %%
g=sns.catplot(data=df[(df.L_0==2.0)&(df.Gamma_a==0.1)], x="Gamma_A", y="T2D",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)
g.set_axis_labels(r"$\Gamma_A$", r"$T^{2D}$")

g=sns.catplot(data=df[(df.L_0==2.0)&(df.Gamma_A==-0.5)], x="Gamma_a", y="T2D",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)
g.set_axis_labels(r"$\Gamma_A$", r"$T^{2D}$")

g=sns.catplot(data=df[(df.Gamma_A==-0.5)&(df.Gamma_a==0.1)], x="L_0", y="T2D",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)
g.set_axis_labels(r"$\Gamma_A$", r"$T^{2D}$")
# Out:
# C:\Users\v35431nc\AppData\Local\Temp\ipykernel_16764\2860035226.py:1: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   g=sns.catplot(data=df[(df.L_0==2.0)&(df.Gamma_a==0.1)], x="Gamma_A", y="T2D",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)
# C:\Users\v35431nc\AppData\Local\Temp\ipykernel_16764\2860035226.py:4: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   g=sns.catplot(data=df[(df.L_0==2.0)&(df.Gamma_A==-0.5)], x="Gamma_a", y="T2D",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)
# C:\Users\v35431nc\AppData\Local\Temp\ipykernel_16764\2860035226.py:7: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   g=sns.catplot(data=df[(df.Gamma_A==-0.5)&(df.Gamma_a==0.1)], x="L_0", y="T2D",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)

# %%
g=sns.catplot(data=df[(df.L_0==2.0)&(df.Gamma_a==0.1)&(df.Gamma_A.isin([-1.0,-1.1, -1.2, -1.3, -1.4, -1.45, -1.5]))], x="Gamma_A", y="shape_param",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)
g.set_axis_labels(r"$\Gamma_A$", "Shape Parameter")
g.refline(y=3.81)
# Out:
# C:\Users\v35431nc\AppData\Local\Temp\ipykernel_16764\921538020.py:1: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   g=sns.catplot(data=df[(df.L_0==2.0)&(df.Gamma_a==0.1)&(df.Gamma_A.isin([-1.0,-1.1, -1.2, -1.3, -1.4, -1.45, -1.5]))], x="Gamma_A", y="shape_param",hue="Edges", kind="box", palette=sns.color_palette("colorblind"), aspect=2)

# %%
evH285=np.loadtxt(savedir + "evalH_Γa_0.1_ΓA_-0.5_ΓL_0.1_L0_2.85.csv")
evH2875=np.loadtxt(savedir + "evalH_Γa_0.1_ΓA_-0.5_ΓL_0.1_L0_2.875.csv")
evH29=np.loadtxt(savedir + "evalH_Γa_0.1_ΓA_-0.5_ΓL_0.1_L0_2.9.csv")
evH2925=np.loadtxt(savedir + "evalH_Γa_0.1_ΓA_-0.5_ΓL_0.1_L0_2.925.csv")
evH295=np.loadtxt(savedir + "evalH_Γa_0.1_ΓA_-0.5_ΓL_0.1_L0_2.95.csv")

# %%
n=np.linspace(1,len(evH285),len(evH285))
# n1=np.linspace(1,len(evH285),len(evH285))
# n2=np.linspace(1,len(evH285),len(evH285))
# n3=np.linspace(1,len(evH285),len(evH285))
size=2
fig = plt.figure()
ax = plt.subplot()

ax.scatter(n[3:],sorted(abs(evH285))[3:], s=size, label=r"$L_0 = 2.85$")
ax.scatter(n[3:],sorted(abs(evH2875))[3:], s=size, label=r"$L_0 = 2.875$")
ax.scatter(n[3:],sorted(abs(evH29))[3:], s=size, label=r"$L_0 = 2.9$")
ax.scatter(n[3:],sorted(abs(evH2925))[3:], s=size, label=r"$L_0 = 2.925$")
ax.scatter(n[3:],sorted(abs(evH295))[3:], s=size, label=r"$L_0 = 2.95$")


#ax.scatter(n,hex_284, s=size, label="Hexagons", c='black')


ax.set_yscale('log')
plt.legend()
ax.set_title("Hessian Eigenvalues")
ax.set_ylabel(r"$\lambda_n$", rotation=0)
ax.set_xlabel("n")
# Out:
# Text(0.5, 0, 'n')
